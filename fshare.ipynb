# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import requests
import os
import datetime

#ENV
your_email_login = ''
your_password = ''
app_key = 'dMnqMMZMUnN5YpvKENaEhdQQ5jxDqddt'
URL_root = "https://www.fshare.vn/folder/SJ2C926FC5D8"

# root_path = "/content/gdrive/MyDrive/Colab Notebooks/dataset/anime/dataset_raw/fshare"
# root_path = "/content/gdrive/MyDrive/Z/fshare"
root_path = "/content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/"
save_name = 'Sakura Miura'
save_path = os.path.join(root_path,save_name)
if not os.path.exists(save_path):
    os.mkdir(save_path)
os.environ['SAVE_FOLDER'] = save_path
SAVE_FOLDER = save_path

# %%
# !sudo apt-get install aria2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libc-ares2
# The following NEW packages will be installed:
#   aria2 libc-ares2
# 0 upgraded, 2 newly installed, 0 to remove and 40 not upgraded.
# Need to get 1,274 kB of archives.
# After this operation, 4,912 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libc-ares2 amd64 1.14.0-1 [37.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 aria2 amd64 1.33.1-1 [1,236 kB]
# Fetched 1,274 kB in 1s (1,605 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# ...

# %% [markdown]
# #1. LOGIN

# %%
token = ''
session_id = ''
url = "https://api.fshare.vn/api/user/login"

payload="{\n\t\"user_email\" : \"%s\",\n\t\"password\":\t\"%s\",\n\t\"app_key\" : \"%s\"\n}" %(your_email_login, your_password, app_key)

headers = {
  'Content-Type': 'application/json',
  'User-Agent': 'testAPI0-AAAN03'
}

response = requests.request("POST", url, headers=headers, data=payload).json()

print(response)
token = response['token']
session_id = response['session_id']
print(token, session_id)
# Out:
# {'code': 200, 'msg': 'Login successfully!', 'token': '6ad11c3288e88208b8570aedcab9652fc7f2767b', 'session_id': 'um65vsdvrn70i7v0ueee8bi4u4'}
# 6ad11c3288e88208b8570aedcab9652fc7f2767b um65vsdvrn70i7v0ueee8bi4u4

# %% [markdown]
# #2. GET LINK FILE FROM FOLDER

# %%
url = "https://api.fshare.vn/api/fileops/getFolderList"

payload="{\n\t\"token\" : \"%s\",\n\t\"url\":\t\"%s\",\n\t\"dirOnly\": 0,\n\t\"pageIndex\": 0,\n\t\"limit\": 250\n}" % (token,URL_root)
headers = {
  'Content-Type': 'application/json',
  'User-Agent': 'TEST APP',
  'Cookie': 'session_id=%s' % (session_id)
}

response = requests.request("POST", url, headers=headers, data=payload).json()

output_name =  save_name+(datetime.datetime.now().strftime("%x")).replace('/','')+".txt"
output_path = os.path.join(save_path,output_name)
with open(output_path, 'w') as out:
        out.write(str(response))
        print('output_path: ',output_path, '----ok----')
print(response)
print(len(response))
# Out:
# output_path:  /content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura/Sakura Miura072921.txt ----ok----
# ...

# %% [markdown]
# #3. GET LINK DOWNLOAD

# %%
url = "https://api.fshare.vn/api/session/download"
output_txt = ""
for episode in response:
    URL = "https://www.fshare.vn/file/" + episode['linkcode']

    payload="{\n\t\"zipflag\" : 0,\n\t\"url\" : \"%s\",\n\t\"password\" : \"\",\n\t\"token\": \"%s\"\n}" % (URL, token)

    headers = {
      'Content-Type': 'application/json',
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
      'User-Agent': 'TEST APP',
      'Authorization': 'Bearer efdf39c90189ddfbff339ae344c28db5f6c11885',
      'Cookie': 'session_id=%s' % (session_id)
    }
    re = requests.request("POST", url, headers=headers, data=payload).json()
    print(re["location"])
    output_txt += str(re["location"]) + '\n'
output_name = save_name+(datetime.datetime.now().strftime("%x")).replace('/','')+"_link.txt"
output_path = os.path.join(save_path,output_name)
with open(output_path, 'w') as out:
        out.write(output_txt)
        print('output_path: ',output_path, '----ok----')
    # print(response)

# %%
os.environ['OUTPUT_PATH'] = output_path
# !export | grep OUTPUT_PATH
# !export | grep SAVE_FOLDER
# Out:
# declare -x OUTPUT_PATH="/content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura/Sakura Miura072921_link.txt"
# declare -x SAVE_FOLDER="/content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura"

# %%
# !aria2c -x 16 -i "${OUTPUT_PATH}" --max-concurrent-downloads=1 --split=16 --min-split-size=1M --download-result=full --file-allocation=none -d "${SAVE_FOLDER}"

# %%
# !aria2c -x 16 -i "${OUTPUT_PATH}" -d "${SAVE_FOLDER}"

# %%
# !aria2c -x 16 -i "${OUTPUT_PATH}" -d "${SAVE_FOLDER}"
#!aria2c "http://download046.fshare.vn/dl/yjbaeXcbDnatP-6ilPV2dX4SYwZAeAAg5nKvxzZMd35MWShuyuQ-FspTuJ3IGjdN0QzhFXnGYYN+HO2G/Better.Call.Saul.S04E01.Smoke.1080p.NF.WEB-DL.DDP5.1.x264.mkv"
# Out:
# 07/29 02:23:58 [NOTICE] Downloading 119 item(s)
#
# 07/29 02:23:58 [NOTICE] Removed the defunct control file /content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura/CW2D2BD-01.iso.aria2 because the download file /content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura/CW2D2BD-01.iso doesn't exist.
#
# 07/29 02:23:58 [NOTICE] Allocating disk space. Use --file-allocation=none to disable it. See --file-allocation option in man page for more details.
#  *** Download Progress Summary as of Thu Jul 29 02:24:58 2021 ***
# =
# [#9cc980 2.0GiB/22GiB(9%) CN:0 DL:0B]
# FILE: /content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura/BD-M07.iso
# -
# [#4f7d95 0B/22GiB(0%) CN:1 DL:0B]
# FILE: /content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura/BD-M08.iso
# -
# [#144d7e 0B/22GiB(0%) CN:1 DL:0B]
# FILE: /content/gdrive/MyDrive/Colab Notebooks/dataset/film/bluray/Sakura Miura/BD-M12.iso
# -
# [#06f248 0B/18GiB(0%) CN:1 DL:0B]
# ...

# %%
# !aria2c --help

# %%
# %cd "/content/gdrive/MyDrive/Colab Notebooks/dataset/film/Peaky_Blinders"
# !aria2c "https://download029.fshare.vn/dl/8msygJ7jHfOZcRVrLL9viR1OwtUzC5++ct5fQt0vqNw3X6bjPUUhAoerR9nqzTibj06NWHOGwPo43jDa/Peaky%20Blinders%20S01E01%20BluRay%201080i%20REMUX%20AVC%20DTS%20HD%205.1%20-%20AYA.mkv"

# %% [markdown]
# # JAV

# %%
code = ["36CYJIMDQB23", "E42RECB7UCW8", "EGUM93GOSOPA", "B6NGZDNTUL6S"]
response = []
for c in code:
  response.append({'linkcode':c})
print(response)
# Out:
# [{'linkcode': '36CYJIMDQB23'}, {'linkcode': 'E42RECB7UCW8'}, {'linkcode': 'EGUM93GOSOPA'}, {'linkcode': 'B6NGZDNTUL6S'}]

# %%
url = "https://api.fshare.vn/api/session/download"
output_txt = ""
for episode in response:
    URL = "https://www.fshare.vn/file/" + episode['linkcode']

    payload="{\n\t\"zipflag\" : 0,\n\t\"url\" : \"%s\",\n\t\"password\" : \"\",\n\t\"token\": \"%s\"\n}" % (URL, token)

    headers = {
      'Content-Type': 'application/json',
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
      'User-Agent': 'TEST APP',
      'Authorization': 'Bearer efdf39c90189ddfbff339ae344c28db5f6c11885',
      'Cookie': 'session_id=%s' % (session_id)
    }
    re = requests.request("POST", url, headers=headers, data=payload).json()
    print(re["location"])
    output_txt += str(re["location"]) + '\n'
output_name = save_name+(datetime.datetime.now().strftime("%x")).replace('/','')+"_link.txt"
output_path = os.path.join(save_path,output_name)
with open(output_path, 'w') as out:
        out.write(output_txt)
        print('output_path: ',output_path, '----ok----')
    # print(response)
# Out:
# http://download029.fshare.vn/dl/kMjocWJmVLxKLhbntsdtIM6bnwpDIoLfxCJG+fKTRkiXMvCOHcYMhVzxjX+lnVnemfcyS5vrkjoLD+I2/DDHH-020%204k.mp4
# http://download011.fshare.vn/dl/W2KyCxy28AusNinFHB6QVIDNZk5Q+9Epd+5+6E9Ae-xWAjBf3oAd+NGPyKrLCEvtDYvJy6-jQYFYKCLR/DDHH-026%20A2.mp4
# http://download025.fshare.vn/dl/u5NrML0jLNXVI4oUB3i6vxlBEDtHQSNU8+u5bODmPIkzqpsrZjUrV72oIjCswbP+L-dteYsqN3sknKTc/DDHH-027%20F1X.mp4
# http://download031.fshare.vn/dl/DFU43BWtC7Ah7eMVhH3srFFNbcmAYs--T0zrRPo-x3JDyGb4jYr4ENo3hdzRffk9aG9D+lleyZyFlIeZ/DDHH-028%20A5X.mp4
# output_path:  /content/gdrive/MyDrive/Z/fshare/HHDD/HHDD062421_link.txt ----ok----

# %% [markdown]
# # LIST LINK FOLDER FSHARE

# %%
url = "https://api.fshare.vn/api/fileops/getFolderList"

payload="{\n\t\"token\" : \"%s\",\n\t\"url\":\t\"%s\",\n\t\"dirOnly\": 0,\n\t\"pageIndex\": 0,\n\t\"limit\": 250\n}" % (token,URL_root)
headers = {
  'Content-Type': 'application/json',
  'User-Agent': 'TEST APP',
  'Cookie': 'session_id=%s' % (session_id)
}

response = requests.request("POST", url, headers=headers, data=payload).json()

output_name =  save_name+(datetime.datetime.now().strftime("%x")).replace('/','')+".txt"
output_path = os.path.join(save_path,output_name)
with open(output_path, 'w') as out:
        out.write(str(response))
        print('output_path: ',output_path, '----ok----')
print(response)
print(len(response))
# Out:
# output_path:  /content/gdrive/MyDrive/Colab Notebooks/dataset/anime/dataset_raw/fshare/Bo Suu Tap Hoat Hinh/Bo Suu Tap Hoat Hinh062221.txt ----ok----
# ...

# %%
import pandas as pd
import re

folder_URL_csv = pd.DataFrame(columns = ['Name','link'])

for r in response:
    
    # print(r['furl'])
    # name = r['ftitle'].replace('(SubViet)|(TMTV)|ViE|mHD|BluRay|DD5.1|x264-TRiM|Longtieng','')
    name = re.sub("(SubViet)|(TMTV)|ViE|mHD|BluRay|DD5.1|x264-TRiM|(Longtieng)|(Long Tieng)|(Thuyet Minh - )|720p|x264|(SubVN)|(SubEng)|DUB|1080p|DTS|-KiTE - |DVDRip|VIE|(Lồng Tiếng)", "", r['ftitle']).replace('()','')
    print(name)
    link = r['furl']
    folder_URL_csv.loc[len(folder_URL_csv)] = [name,link]

folder_URL_csv.to_csv('test.csv',index=False)
